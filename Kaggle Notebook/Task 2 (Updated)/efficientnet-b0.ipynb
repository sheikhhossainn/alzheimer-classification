# %%
import os
import random
import time
import gc
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

if 'strategy' not in locals():
    try:
        strategy = tf.distribute.MirroredStrategy()
        print(f" Dual-GPU Strategy Initialized. Replicas: {strategy.num_replicas_in_sync}")
    except Exception as e:
        print(f" GPU initialization failed: {e}")
        strategy = tf.distribute.get_strategy()
else:
    print(f" Strategy already active. Replicas: {strategy.num_replicas_in_sync}")

BATCH_SIZE = 32 * strategy.num_replicas_in_sync
AUTOTUNE = tf.data.AUTOTUNE
DATA_DIR = '/kaggle/input/datasets/uraninjo/augmented-alzheimer-mri-dataset-v2'

print("\nFetching Local File Paths...")
filepaths = []
for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            filepaths.append(os.path.join(root, file))

labels = [os.path.basename(os.path.dirname(path)) for path in filepaths]
df = pd.DataFrame({'filepath': filepaths, 'label': labels})
class_names = sorted(df['label'].unique())
class_indices = {name: idx for idx, name in enumerate(class_names)}
df['label_idx'] = df['label'].map(class_indices)

print(f" Successfully pooled {len(df)} images.")
print(f"Classes found: {class_indices}")

def decode_image(filepath, label):
    image_bytes = tf.io.read_file(filepath)
    image = tf.io.decode_image(image_bytes, channels=3, expand_animations=False)
    image = tf.image.resize(image, [224, 224])
    image = preprocess_input(image)
    label = tf.one_hot(label, depth=len(class_names))
    return image, label

def decode_image_predict_only(filepath):
    image_bytes = tf.io.read_file(filepath)
    image = tf.io.decode_image(image_bytes, channels=3, expand_animations=False)
    image = tf.image.resize(image, [224, 224])
    image = preprocess_input(image)
    return image

def build_dataset(dataframe, is_training=False):
    dataset = tf.data.Dataset.from_tensor_slices((dataframe['filepath'].values, dataframe['label_idx'].values))
    dataset = dataset.map(decode_image, num_parallel_calls=AUTOTUNE)
    if is_training:
        dataset = dataset.shuffle(buffer_size=2048, seed=SEED)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return dataset

def build_predict_dataset(dataframe):
    dataset = tf.data.Dataset.from_tensor_slices(dataframe['filepath'].values)
    dataset = dataset.map(decode_image_predict_only, num_parallel_calls=AUTOTUNE, deterministic=True)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return dataset

def build_efficientnet_model():
    tf.keras.backend.clear_session()
    with strategy.scope():
        base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        base_model.trainable = False
        x = GlobalAveragePooling2D()(base_model.output)
        x = Dense(256, activation='relu')(x)
        x = Dropout(0.5)(x)
        outputs = Dense(len(class_names), activation='softmax')(x)
        model = Model(inputs=base_model.input, outputs=outputs)
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
    return model

K_FOLDS = 5
EPOCHS = 50

skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

fold_accuracies  = []
fold_f1_scores   = []
fold_precisions  = []
fold_recalls     = []
fold_conf_matrices = []

print("\n STARTING 5-FOLD CROSS-VALIDATION (EfficientNetB0 on T4 x2 GPUs)...")
start_time = time.time()

for fold, (train_val_idx, test_idx) in enumerate(skf.split(df['filepath'], df['label_idx'])):
    fold_num = fold + 1
    print(f"\n{'='*50}\n STARTING FOLD {fold_num} / {K_FOLDS}\n{'='*50}")

    test_df      = df.iloc[test_idx]
    train_val_df = df.iloc[train_val_idx]
    train_df, val_df = train_test_split(
        train_val_df, test_size=0.1,
        stratify=train_val_df['label_idx'], random_state=SEED
    )

    train_ds   = build_dataset(train_df, is_training=True)
    val_ds     = build_dataset(val_df, is_training=False)
    test_ds    = build_dataset(test_df, is_training=False)
    predict_ds = build_predict_dataset(test_df)

    model = build_efficientnet_model()

    checkpoint_path = f'/kaggle/working/best_efficientnetb0_fold_{fold_num}.keras'
    checkpoint      = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
    early_stopping  = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1)

    print("\n Training Model...")
    history = model.fit(
        train_ds, validation_data=val_ds,
        epochs=EPOCHS, callbacks=[checkpoint, early_stopping], verbose=1
    )

    print(f"\n Generating Training Curves for Fold {fold_num}...")
    plt.figure(figsize=(14, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    plt.title(f'Fold {fold_num}: Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
    plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    plt.title(f'Fold {fold_num}: Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()  

    print("\n Evaluating on unseen Pure Test Set...")
    model.load_weights(checkpoint_path)

    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    fold_accuracies.append(test_acc)

    true_labels = test_df['label_idx'].values
    pred_probs  = model.predict(predict_ds, verbose=0)
    pred_labels = np.argmax(pred_probs, axis=1)

    f1   = f1_score(true_labels, pred_labels, average='weighted')
    prec = precision_score(true_labels, pred_labels, average='weighted')
    rec  = recall_score(true_labels, pred_labels, average='weighted')
    cm   = confusion_matrix(true_labels, pred_labels)

    fold_f1_scores.append(f1)
    fold_precisions.append(prec)
    fold_recalls.append(rec)
    fold_conf_matrices.append(cm)

    print(f"\n Generating Confusion Matrix for Fold {fold_num}...")
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Fold {fold_num}: Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.tight_layout()
    plt.show()  

    print(f" Fold {fold_num} | Acc: {test_acc*100:.2f}% | F1: {f1:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f}")

    print(" Wiping GPU Memory clean for the next fold...")
    del model, train_ds, val_ds, test_ds, predict_ds, history
    tf.keras.backend.clear_session()
    gc.collect()

np.save('/kaggle/working/EfficientNetB0_5Fold_Accuracies_DualGPU.npy',  np.array(fold_accuracies))
np.save('/kaggle/working/EfficientNetB0_5Fold_F1_DualGPU.npy',          np.array(fold_f1_scores))
np.save('/kaggle/working/EfficientNetB0_5Fold_Precision_DualGPU.npy',   np.array(fold_precisions))
np.save('/kaggle/working/EfficientNetB0_5Fold_Recall_DualGPU.npy',      np.array(fold_recalls))
np.save('/kaggle/working/EfficientNetB0_5Fold_ConfMatrix_DualGPU.npy',  np.array(fold_conf_matrices))

print(f"\n ALL {K_FOLDS} FOLDS COMPLETE!")
print(f" Avg Accuracy  : {np.mean(fold_accuracies)*100:.2f}% (+/- {np.std(fold_accuracies)*100:.2f}%)")
print(f" Avg F1 Score  : {np.mean(fold_f1_scores):.4f} (+/- {np.std(fold_f1_scores):.4f})")
print(f" Avg Precision : {np.mean(fold_precisions):.4f} (+/- {np.std(fold_precisions):.4f})")
print(f" Avg Recall    : {np.mean(fold_recalls):.4f} (+/- {np.std(fold_recalls):.4f})")
print(f" Total Experiment Time: {(time.time() - start_time) / 60:.2f} minutes")
# Out:
# 2026-04-24 12:37:57.461951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777034277.694866      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777034277.760161      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777034278.289610      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777034278.289669      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777034278.289675      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777034278.289679      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# I0000 00:00:1777034305.471044      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777034305.476826      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
#  Dual-GPU Strategy Initialized. Replicas: 2
#
# Fetching Local File Paths...
#  Successfully pooled 40384 images.
# Classes found: {'MildDemented': 0, 'ModerateDemented': 1, 'NonDemented': 2, 'VeryMildDemented': 3}
#
#  STARTING 5-FOLD CROSS-VALIDATION (EfficientNetB0 on T4 x2 GPUs)...
#
# ==================================================
#  STARTING FOLD 1 / 5
# ==================================================
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
#  Training Model...
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 4 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# E0000 00:00:1777034438.107697      23 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1777034442.029485      70 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1777034442.640990      69 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.3824 - loss: 1.2970INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_accuracy improved from -inf to 0.57784, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 123s 238ms/step - accuracy: 0.3825 - loss: 1.2968 - val_accuracy: 0.5778 - val_loss: 1.0055
# Epoch 2/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5283 - loss: 1.0549
# Epoch 2: val_accuracy improved from 0.57784 to 0.62798, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 65s 138ms/step - accuracy: 0.5283 - loss: 1.0548 - val_accuracy: 0.6280 - val_loss: 0.8932
# Epoch 3/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5743 - loss: 0.9587
# Epoch 3: val_accuracy improved from 0.62798 to 0.65614, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 131ms/step - accuracy: 0.5743 - loss: 0.9586 - val_accuracy: 0.6561 - val_loss: 0.8217
# Epoch 4/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6088 - loss: 0.8936
# Epoch 4: val_accuracy improved from 0.65614 to 0.67162, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 63s 133ms/step - accuracy: 0.6088 - loss: 0.8935 - val_accuracy: 0.6716 - val_loss: 0.7807
# Epoch 5/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6223 - loss: 0.8547
# Epoch 5: val_accuracy improved from 0.67162 to 0.69359, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 63s 134ms/step - accuracy: 0.6223 - loss: 0.8547 - val_accuracy: 0.6936 - val_loss: 0.7419
# Epoch 6/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6392 - loss: 0.8176
# Epoch 6: val_accuracy improved from 0.69359 to 0.69885, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 63s 135ms/step - accuracy: 0.6392 - loss: 0.8176 - val_accuracy: 0.6989 - val_loss: 0.7157
# Epoch 7/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6474 - loss: 0.7899
# Epoch 7: val_accuracy improved from 0.69885 to 0.70752, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 64s 134ms/step - accuracy: 0.6474 - loss: 0.7899 - val_accuracy: 0.7075 - val_loss: 0.6954
# Epoch 8/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6602 - loss: 0.7714
# Epoch 8: val_accuracy improved from 0.70752 to 0.71650, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 64s 136ms/step - accuracy: 0.6602 - loss: 0.7714 - val_accuracy: 0.7165 - val_loss: 0.6779
# Epoch 9/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6703 - loss: 0.7515
# Epoch 9: val_accuracy improved from 0.71650 to 0.71866, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 64s 137ms/step - accuracy: 0.6703 - loss: 0.7515 - val_accuracy: 0.7187 - val_loss: 0.6630
# Epoch 10/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6735 - loss: 0.7355
# Epoch 10: val_accuracy improved from 0.71866 to 0.73259, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 63s 133ms/step - accuracy: 0.6736 - loss: 0.7354 - val_accuracy: 0.7326 - val_loss: 0.6430
# Epoch 11/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6893 - loss: 0.7137
# Epoch 11: val_accuracy did not improve from 0.73259
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 130ms/step - accuracy: 0.6893 - loss: 0.7137 - val_accuracy: 0.7273 - val_loss: 0.6333
# Epoch 12/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 60s 129ms/step - accuracy: 0.8083 - loss: 0.4632 - val_accuracy: 0.8496 - val_loss: 0.3815
# Epoch 43/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8177 - loss: 0.4546
# Epoch 43: val_accuracy improved from 0.85392 to 0.86753, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 132ms/step - accuracy: 0.8177 - loss: 0.4545 - val_accuracy: 0.8675 - val_loss: 0.3700
# Epoch 44/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8203 - loss: 0.4476
# Epoch 44: val_accuracy did not improve from 0.86753
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 61s 132ms/step - accuracy: 0.8203 - loss: 0.4476 - val_accuracy: 0.8604 - val_loss: 0.3642
# Epoch 45/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8166 - loss: 0.4503
# Epoch 45: val_accuracy improved from 0.86753 to 0.87249, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 134ms/step - accuracy: 0.8166 - loss: 0.4503 - val_accuracy: 0.8725 - val_loss: 0.3549
# Epoch 46/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8203 - loss: 0.4421
# Epoch 46: val_accuracy did not improve from 0.87249
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 61s 131ms/step - accuracy: 0.8203 - loss: 0.4420 - val_accuracy: 0.8675 - val_loss: 0.3554
# Epoch 47/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8280 - loss: 0.4357
# Epoch 47: val_accuracy improved from 0.87249 to 0.87372, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 134ms/step - accuracy: 0.8280 - loss: 0.4357 - val_accuracy: 0.8737 - val_loss: 0.3460
# Epoch 48/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8283 - loss: 0.4335
# Epoch 48: val_accuracy improved from 0.87372 to 0.87806, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 63s 132ms/step - accuracy: 0.8283 - loss: 0.4335 - val_accuracy: 0.8781 - val_loss: 0.3471
# Epoch 49/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8289 - loss: 0.4253
# Epoch 49: val_accuracy improved from 0.87806 to 0.88301, saving model to /kaggle/working/best_efficientnetb0_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 63s 135ms/step - accuracy: 0.8289 - loss: 0.4253 - val_accuracy: 0.8830 - val_loss: 0.3385
# Epoch 50/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8282 - loss: 0.4292
# Epoch 50: val_accuracy did not improve from 0.88301
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 133ms/step - accuracy: 0.8282 - loss: 0.4292 - val_accuracy: 0.8793 - val_loss: 0.3311
# Restoring model weights from the end of the best epoch: 49.
#
#  Generating Training Curves for Fold 1...
#  Evaluating on unseen Pure Test Set...
#
#  Generating Confusion Matrix for Fold 1...
#  Fold 1 | Acc: 88.25% | F1: 0.8820 | Precision: 0.8818 | Recall: 0.8825
#  Wiping GPU Memory clean for the next fold...
#
# ==================================================
#  STARTING FOLD 2 / 5
# ==================================================
#
#  Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 4 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# E0000 00:00:1777037727.460734      23 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3850 - loss: 1.2943
# Epoch 1: val_accuracy improved from -inf to 0.58186, saving model to /kaggle/working/best_efficientnetb0_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 73s 136ms/step - accuracy: 0.3852 - loss: 1.2939 - val_accuracy: 0.5819 - val_loss: 1.0159
# Epoch 2/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5362 - loss: 1.0458
# Epoch 2: val_accuracy improved from 0.58186 to 0.62024, saving model to /kaggle/working/best_efficientnetb0_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 60s 128ms/step - accuracy: 0.5363 - loss: 1.0456 - val_accuracy: 0.6202 - val_loss: 0.9046
# Epoch 3/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5796 - loss: 0.9492
# Epoch 3: val_accuracy improved from 0.62024 to 0.63974, saving model to /kaggle/working/best_efficientnetb0_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 59s 126ms/step - accuracy: 0.5796 - loss: 0.9491 - val_accuracy: 0.6397 - val_loss: 0.8348
# Epoch 4/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6074 - loss: 0.8854
# Epoch 4: val_accuracy improved from 0.63974 to 0.66388, saving model to /kaggle/working/best_efficientnetb0_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 60s 128ms/step - accuracy: 0.6074 - loss: 0.8853 - val_accuracy: 0.6639 - val_loss: 0.7889
# Epoch 5/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 59s 126ms/step - accuracy: 0.8371 - loss: 0.4093 - val_accuracy: 0.8759 - val_loss: 0.3352
# Restoring model weights from the end of the best epoch: 49.
#
#  Generating Training Curves for Fold 2...
#  Evaluating on unseen Pure Test Set...
#
#  Generating Confusion Matrix for Fold 2...
#  Fold 2 | Acc: 87.50% | F1: 0.8746 | Precision: 0.8744 | Recall: 0.8750
#  Wiping GPU Memory clean for the next fold...
#
# ==================================================
#  STARTING FOLD 3 / 5
# ==================================================
#
#  Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 4 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# E0000 00:00:1777040751.801346      23 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3857 - loss: 1.2969
# Epoch 1: val_accuracy improved from -inf to 0.57691, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 77s 145ms/step - accuracy: 0.3860 - loss: 1.2965 - val_accuracy: 0.5769 - val_loss: 1.0010
# Epoch 2/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5349 - loss: 1.0376
# Epoch 2: val_accuracy improved from 0.57691 to 0.62396, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 132ms/step - accuracy: 0.5349 - loss: 1.0375 - val_accuracy: 0.6240 - val_loss: 0.8934
# Epoch 3/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5846 - loss: 0.9429
# Epoch 3: val_accuracy improved from 0.62396 to 0.64098, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 63s 134ms/step - accuracy: 0.5846 - loss: 0.9428 - val_accuracy: 0.6410 - val_loss: 0.8281
# Epoch 4/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6065 - loss: 0.8870
# Epoch 4: val_accuracy improved from 0.64098 to 0.65460, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 64s 134ms/step - accuracy: 0.6066 - loss: 0.8870 - val_accuracy: 0.6546 - val_loss: 0.7870
# Epoch 5/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6228 - loss: 0.8420
# Epoch 5: val_accuracy improved from 0.65460 to 0.68586, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 133ms/step - accuracy: 0.6229 - loss: 0.8420 - val_accuracy: 0.6859 - val_loss: 0.7513
# Epoch 6/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6457 - loss: 0.8090
# Epoch 6: val_accuracy did not improve from 0.68586
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 133ms/step - accuracy: 0.6457 - loss: 0.8090 - val_accuracy: 0.6840 - val_loss: 0.7229
# Epoch 7/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6524 - loss: 0.7873
# Epoch 7: val_accuracy improved from 0.68586 to 0.69762, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 63s 135ms/step - accuracy: 0.6525 - loss: 0.7873 - val_accuracy: 0.6976 - val_loss: 0.7024
# Epoch 8/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6645 - loss: 0.7624
# Epoch 8: val_accuracy improved from 0.69762 to 0.70659, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 67s 139ms/step - accuracy: 0.6645 - loss: 0.7624 - val_accuracy: 0.7066 - val_loss: 0.6846
# Epoch 9/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6719 - loss: 0.7472
# Epoch 9: val_accuracy improved from 0.70659 to 0.71371, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 64s 132ms/step - accuracy: 0.6720 - loss: 0.7472 - val_accuracy: 0.7137 - val_loss: 0.6681
# Epoch 10/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6741 - loss: 0.7335
# Epoch 10: val_accuracy improved from 0.71371 to 0.72392, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 133ms/step - accuracy: 0.6742 - loss: 0.7334 - val_accuracy: 0.7239 - val_loss: 0.6481
# Epoch 11/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6940 - loss: 0.7070
# Epoch 11: val_accuracy improved from 0.72392 to 0.72671, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 133ms/step - accuracy: 0.6940 - loss: 0.7070 - val_accuracy: 0.7267 - val_loss: 0.6323
# Epoch 12/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6950 - loss: 0.6946
# Epoch 12: val_accuracy improved from 0.72671 to 0.73197, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 133ms/step - accuracy: 0.6950 - loss: 0.6946 - val_accuracy: 0.7320 - val_loss: 0.6181
# Epoch 13/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6963 - loss: 0.6880
# Epoch 13: val_accuracy improved from 0.73197 to 0.74095, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 133ms/step - accuracy: 0.6964 - loss: 0.6879 - val_accuracy: 0.7409 - val_loss: 0.6098
# Epoch 14/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0
50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7858 - loss: 0.5279
# Epoch 30: val_accuracy improved from 0.82668 to 0.82916, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 132ms/step - accuracy: 0.7858 - loss: 0.5279 - val_accuracy: 0.8292 - val_loss: 0.4471
# Epoch 31/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7795 - loss: 0.5241
# Epoch 31: val_accuracy improved from 0.82916 to 0.83411, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 132ms/step - accuracy: 0.7796 - loss: 0.5241 - val_accuracy: 0.8341 - val_loss: 0.4372
# Epoch 32/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.7876 - loss: 0.5145
# Epoch 32: val_accuracy did not improve from 0.83411
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - accuracy: 0.7876 - loss: 0.5145 - val_accuracy: 0.8292 - val_loss: 0.4427
# Epoch 33/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7921 - loss: 0.5045
# Epoch 33: val_accuracy improved from 0.83411 to 0.83751, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 133ms/step - accuracy: 0.7921 - loss: 0.5045 - val_accuracy: 0.8375 - val_loss: 0.4229
# Epoch 34/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7923 - loss: 0.5000
# Epoch 34: val_accuracy did not improve from 0.83751
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 62s 132ms/step - accuracy: 0.7923 - loss: 0.5000 - val_accuracy: 0.8316 - val_loss: 0.4264
# Epoch 35/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7949 - loss: 0.4959
# Epoch 35: val_accuracy improved from 0.83751 to 0.84649, saving model to /kaggle/working/best_efficientnetb0_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - accuracy: 0.7949 - loss: 0.4959 - val_accuracy: 0.8465 - val_loss: 0.4101
# Epoch 36/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7996 - loss: 0.4891
# ...
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3810 - loss: 1.3090
# Epoch 1: val_accuracy improved from -inf to 0.55556, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 75s 137ms/step - accuracy: 0.3812 - loss: 1.3085 - val_accuracy: 0.5556 - val_loss: 1.0196
# Epoch 2/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5291 - loss: 1.0510
# Epoch 2: val_accuracy improved from 0.55556 to 0.63788, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 56s 119ms/step - accuracy: 0.5291 - loss: 1.0509 - val_accuracy: 0.6379 - val_loss: 0.8946
# Epoch 3/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5763 - loss: 0.9570
# Epoch 3: val_accuracy improved from 0.63788 to 0.64345, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 54s 116ms/step - accuracy: 0.5763 - loss: 0.9569 - val_accuracy: 0.6435 - val_loss: 0.8364
# Epoch 4/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6087 - loss: 0.8960
# Epoch 4: val_accuracy improved from 0.64345 to 0.66295, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 54s 115ms/step - accuracy: 0.6087 - loss: 0.8959 - val_accuracy: 0.6630 - val_loss: 0.7863
# Epoch 5/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6208 - loss: 0.8548
# Epoch 5: val_accuracy improved from 0.66295 to 0.67162, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 55s 117ms/step - accuracy: 0.6208 - loss: 0.8548 - val_accuracy: 0.6716 - val_loss: 0.7607
# Epoch 6/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6381 - loss: 0.8201
# Epoch 6: val_accuracy improved from 0.67162 to 0.67409, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 58s 123ms/step - accuracy: 0.6381 - loss: 0.8200 - val_accuracy: 0.6741 - val_loss: 0.7362
# Epoch 7/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6459 - loss: 0.7953
# Epoch 7: val_accuracy improved from 0.67409 to 0.68802, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 57s 122ms/step - accuracy: 0.6459 - loss: 0.7952 - val_accuracy: 0.6880 - val_loss: 0.7061
# Epoch 8/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6623 - loss: 0.7719
# Epoch 8: val_accuracy improved from 0.68802 to 0.70721, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 57s 122ms/step - accuracy: 0.6623 - loss: 0.7718 - val_accuracy: 0.7072 - val_loss: 0.6842
# Epoch 9/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.
50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8116 - loss: 0.4677
# Epoch 39: val_accuracy did not improve from 0.85794
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 59s 123ms/step - accuracy: 0.8116 - loss: 0.4677 - val_accuracy: 0.8539 - val_loss: 0.3874
# Epoch 40/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8149 - loss: 0.4601
# Epoch 40: val_accuracy improved from 0.85794 to 0.85887, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 58s 124ms/step - accuracy: 0.8149 - loss: 0.4601 - val_accuracy: 0.8589 - val_loss: 0.3816
# Epoch 41/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8145 - loss: 0.4561
# Epoch 41: val_accuracy did not improve from 0.85887
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 57s 122ms/step - accuracy: 0.8145 - loss: 0.4561 - val_accuracy: 0.8589 - val_loss: 0.3809
# Epoch 42/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8147 - loss: 0.4510
# Epoch 42: val_accuracy improved from 0.85887 to 0.87094, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 59s 126ms/step - accuracy: 0.8147 - loss: 0.4509 - val_accuracy: 0.8709 - val_loss: 0.3614
# Epoch 43/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8199 - loss: 0.4455
# Epoch 43: val_accuracy improved from 0.87094 to 0.87125, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 59s 126ms/step - accuracy: 0.8199 - loss: 0.4455 - val_accuracy: 0.8712 - val_loss: 0.3606
# Epoch 44/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8247 - loss: 0.4430
# Epoch 44: val_accuracy did not improve from 0.87125
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 58s 124ms/step - accuracy: 0.8247 - loss: 0.4430 - val_accuracy: 0.8678 - val_loss: 0.3601
# Epoch 45/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8265 - loss: 0.4357
# Epoch 45: val_accuracy did not improve from 0.87125
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 58s 124ms/step - accuracy: 0.8265 - loss: 0.4357 - val_accuracy: 0.8682 - val_loss: 0.3612
# Epoch 46/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8312 - loss: 0.4286
# Epoch 46: val_accuracy improved from 0.87125 to 0.87682, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 58s 125ms/step - accuracy: 0.8311 - loss: 0.4286 - val_accuracy: 0.8768 - val_loss: 0.3455
# Epoch 47/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8309 - loss: 0.4248
# Epoch 47: val_accuracy improved from 0.87682 to 0.87929, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 58s 125ms/step - accuracy: 0.8309 - loss: 0.4248 - val_accuracy: 0.8793 - val_loss: 0.3393
# Epoch 48/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8330 - loss: 0.4182
# Epoch 48: val_accuracy did not improve from 0.87929
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 58s 123ms/step - accuracy: 0.8330 - loss: 0.4182 - val_accuracy: 0.8747 - val_loss: 0.3436
# Epoch 49/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8344 - loss: 0.4198
# Epoch 49: val_accuracy improved from 0.87929 to 0.88146, saving model to /kaggle/working/best_efficientnetb0_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 58s 124ms/step - accuracy: 0.8344 - loss: 0.4198 - val_accuracy: 0.8815 - val_loss: 0.3368
# Epoch 50/50
# 454/455 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8338 - loss: 0.4178
# Epoch 50: val_accuracy did not improve from 0.88146
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 57s 123ms/step - accuracy: 0.8338 - loss: 0.4178 - val_accuracy: 0.8765 - val_loss: 0.3365
# Restoring model weights from the end of the best epoch: 49.
#
#  Generating Training Curves for Fold 5...
#  Evaluating on unseen Pure Test Set...
#
#  Generating Confusion Matrix for Fold 5...
#  Fold 5 | Acc: 88.09% | F1: 0.8808 | Precision: 0.8813 | Recall: 0.8809
#  Wiping GPU Memory clean for the next fold...
#
#  ALL 5 FOLDS COMPLETE!
#  Avg Accuracy  : 88.00% (+/- 0.27%)
#  Avg F1 Score  : 0.8797 (+/- 0.0028)
#  Avg Precision : 0.8798 (+/- 0.0030)
#  Avg Recall    : 0.8800 (+/- 0.0027)
#  Total Experiment Time: 255.88 minutes
