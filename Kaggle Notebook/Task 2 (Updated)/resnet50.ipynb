# %%
import os
import random
import time
import gc
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

if 'strategy' not in locals():
    try:
        strategy = tf.distribute.MirroredStrategy()
        print(f"✅ Dual-GPU Strategy Initialized. Replicas: {strategy.num_replicas_in_sync}")
    except Exception as e:
        print(f"❌ GPU initialization failed: {e}")
        strategy = tf.distribute.get_strategy()
else:
    print(f"⚡ Strategy already active. Replicas: {strategy.num_replicas_in_sync}")

BATCH_SIZE = 32 * strategy.num_replicas_in_sync
AUTOTUNE = tf.data.AUTOTUNE
DATA_DIR = '/kaggle/input/datasets/uraninjo/augmented-alzheimer-mri-dataset-v2'

print("\nFetching Local File Paths...")
filepaths = []
for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            filepaths.append(os.path.join(root, file))

labels = [os.path.basename(os.path.dirname(path)) for path in filepaths]
df = pd.DataFrame({'filepath': filepaths, 'label': labels})
class_names = sorted(df['label'].unique())
class_indices = {name: idx for idx, name in enumerate(class_names)}
df['label_idx'] = df['label'].map(class_indices)

print(f"✅ Successfully pooled {len(df)} images.")
print(f"Classes found: {class_indices}")

def decode_image(filepath, label):
    image_bytes = tf.io.read_file(filepath)
    image = tf.io.decode_image(image_bytes, channels=3, expand_animations=False)
    image = tf.image.resize(image, [224, 224])
    image = preprocess_input(image)
    label = tf.one_hot(label, depth=len(class_names))
    return image, label

def decode_image_predict_only(filepath):
    image_bytes = tf.io.read_file(filepath)
    image = tf.io.decode_image(image_bytes, channels=3, expand_animations=False)
    image = tf.image.resize(image, [224, 224])
    image = preprocess_input(image)
    return image

def build_dataset(dataframe, is_training=False):
    dataset = tf.data.Dataset.from_tensor_slices((dataframe['filepath'].values, dataframe['label_idx'].values))
    dataset = dataset.map(decode_image, num_parallel_calls=AUTOTUNE)
    if is_training:
        dataset = dataset.shuffle(buffer_size=2048, seed=SEED)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return dataset

def build_predict_dataset(dataframe):
    dataset = tf.data.Dataset.from_tensor_slices(dataframe['filepath'].values)
    dataset = dataset.map(decode_image_predict_only, num_parallel_calls=AUTOTUNE, deterministic=True)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return dataset

def build_resnet_model():
    tf.keras.backend.clear_session()
    with strategy.scope():
        base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        base_model.trainable = False
        x = GlobalAveragePooling2D()(base_model.output)
        x = Dense(256, activation='relu')(x)
        x = Dropout(0.5)(x)
        outputs = Dense(len(class_names), activation='softmax')(x)
        model = Model(inputs=base_model.input, outputs=outputs)
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
    return model

K_FOLDS = 5
EPOCHS = 50

skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

fold_accuracies  = []
fold_f1_scores   = []
fold_precisions  = []
fold_recalls     = []
fold_conf_matrices = []

print("\n🚀 STARTING 5-FOLD CROSS-VALIDATION (ResNet50 on T4 x2 GPUs)...")
start_time = time.time()

for fold, (train_val_idx, test_idx) in enumerate(skf.split(df['filepath'], df['label_idx'])):
    fold_num = fold + 1
    print(f"\n{'='*50}\n🧪 STARTING FOLD {fold_num} / {K_FOLDS}\n{'='*50}")

    test_df      = df.iloc[test_idx]
    train_val_df = df.iloc[train_val_idx]
    train_df, val_df = train_test_split(
        train_val_df, test_size=0.1,
        stratify=train_val_df['label_idx'], random_state=SEED
    )

    train_ds   = build_dataset(train_df, is_training=True)
    val_ds     = build_dataset(val_df, is_training=False)
    test_ds    = build_dataset(test_df, is_training=False)
    predict_ds = build_predict_dataset(test_df)

    model = build_resnet_model()

    checkpoint_path = f'/kaggle/working/best_resnet50_fold_{fold_num}.keras'
    checkpoint      = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
    early_stopping  = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1)

    print("\n⏳ Training Model...")
    history = model.fit(
        train_ds, validation_data=val_ds,
        epochs=EPOCHS, callbacks=[checkpoint, early_stopping], verbose=1
    )

    print(f"\n📊 Generating Training Curves for Fold {fold_num}...")
    plt.figure(figsize=(14, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    plt.title(f'Fold {fold_num}: Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
    plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    plt.title(f'Fold {fold_num}: Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.savefig(f'/kaggle/working/resnet50_training_curves_fold_{fold_num}.png', dpi=300)
    plt.close()

    print("\n🔍 Evaluating on unseen Pure Test Set...")
    model.load_weights(checkpoint_path)

    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    fold_accuracies.append(test_acc)

    true_labels = test_df['label_idx'].values
    pred_probs  = model.predict(predict_ds, verbose=0)
    pred_labels = np.argmax(pred_probs, axis=1)

    f1   = f1_score(true_labels, pred_labels, average='weighted')
    prec = precision_score(true_labels, pred_labels, average='weighted')
    rec  = recall_score(true_labels, pred_labels, average='weighted')
    cm   = confusion_matrix(true_labels, pred_labels)

    fold_f1_scores.append(f1)
    fold_precisions.append(prec)
    fold_recalls.append(rec)
    fold_conf_matrices.append(cm)

    print(f"\n📊 Generating Confusion Matrix for Fold {fold_num}...")
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Fold {fold_num}: Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.tight_layout()
    plt.savefig(f'/kaggle/working/resnet50_confusion_matrix_fold_{fold_num}.png', dpi=300)
    plt.close()

    print(f"✅ Fold {fold_num} | Acc: {test_acc*100:.2f}% | F1: {f1:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f}")

    print("🧹 Wiping GPU Memory clean for the next fold...")
    del model, train_ds, val_ds, test_ds, predict_ds, history
    tf.keras.backend.clear_session()
    gc.collect()

np.save('/kaggle/working/ResNet50_5Fold_Accuracies_DualGPU.npy',  np.array(fold_accuracies))
np.save('/kaggle/working/ResNet50_5Fold_F1_DualGPU.npy',          np.array(fold_f1_scores))
np.save('/kaggle/working/ResNet50_5Fold_Precision_DualGPU.npy',   np.array(fold_precisions))
np.save('/kaggle/working/ResNet50_5Fold_Recall_DualGPU.npy',      np.array(fold_recalls))
np.save('/kaggle/working/ResNet50_5Fold_ConfMatrix_DualGPU.npy',  np.array(fold_conf_matrices))

print(f"\n🎉 ALL {K_FOLDS} FOLDS COMPLETE!")
print(f"🏆 Avg Accuracy  : {np.mean(fold_accuracies)*100:.2f}% (+/- {np.std(fold_accuracies)*100:.2f}%)")
print(f"🏆 Avg F1 Score  : {np.mean(fold_f1_scores):.4f} (+/- {np.std(fold_f1_scores):.4f})")
print(f"🏆 Avg Precision : {np.mean(fold_precisions):.4f} (+/- {np.std(fold_precisions):.4f})")
print(f"🏆 Avg Recall    : {np.mean(fold_recalls):.4f} (+/- {np.std(fold_recalls):.4f})")
print(f"⏱️ Total Experiment Time: {(time.time() - start_time) / 60:.2f} minutes")
# Out:
# 2026-04-06 16:08:53.733495: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775491733.960565      25 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775491734.029518      25 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775491734.560290      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775491734.560327      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775491734.560330      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775491734.560332      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# I0000 00:00:1775491762.229670      25 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1775491762.235824      25 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# ✅ Dual-GPU Strategy Initialized. Replicas: 2
#
# Fetching Local File Paths...
# ✅ Successfully pooled 40384 images.
# Classes found: {'MildDemented': 0, 'ModerateDemented': 1, 'NonDemented': 2, 'VeryMildDemented': 3}
#
# 🚀 STARTING 5-FOLD CROSS-VALIDATION (ResNet50 on T4 x2 GPUs)...
#
# ==================================================
# 🧪 STARTING FOLD 1 / 5
# ==================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# ⏳ Training Model...
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 4 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# I0000 00:00:1775492193.091198      70 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1775492193.832833      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.4258 - loss: 1.2988INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_accuracy improved from -inf to 0.63386, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 219s 451ms/step - accuracy: 0.4260 - loss: 1.2984 - val_accuracy: 0.6339 - val_loss: 0.8666
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6001 - loss: 0.8974
# Epoch 2: val_accuracy improved from 0.63386 to 0.67688, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.6001 - loss: 0.8974 - val_accuracy: 0.6769 - val_loss: 0.7651
# Epoch 3/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.6405 - loss: 0.8032
# Epoch 3: val_accuracy improved from 0.67688 to 0.70133, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 105s 219ms/step - accuracy: 0.6405 - loss: 0.8032 - val_accuracy: 0.7013 - val_loss: 0.7100
# Epoch 4/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6761 - loss: 0.7391
# Epoch 4: val_accuracy improved from 0.70133 to 0.71371, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 99s 212ms/step - accuracy: 0.6761 - loss: 0.7390 - val_accuracy: 0.7137 - val_loss: 0.6710
# Epoch 5/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6910 - loss: 0.7020
# Epoch 5: val_accuracy improved from 0.71371 to 0.74002, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 96s 205ms/step - accuracy: 0.6910 - loss: 0.7020 - val_accuracy: 0.7400 - val_loss: 0.6397
# Epoch 6/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7091 - loss: 0.6629
# Epoch 6: val_accuracy improved from 0.74002 to 0.74033, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 109s 226ms/step - accuracy: 0.7091 - loss: 0.6629 - val_accuracy: 0.7403 - val_loss: 0.6079
# Epoch 7/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7247 - loss: 0.6316
# Epoch 7: val_accuracy improved from 0.74033 to 0.76633, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 227ms/step - accuracy: 0.7247 - loss: 0.6316 - val_accuracy: 0.7663 - val_loss: 0.5803
# Epoch 8/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.7325 - loss: 0.6098
# Epoch 8: val_accuracy did not improve from 0.76633
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.7325 - loss: 0.6097 - val_accuracy: 0.7657 - val_loss: 0.5605
# Epoch 9/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.7493 - loss: 0.5829
# Epoch 9: val_accuracy improved from 0.76633 to 0.77809, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.7493 - loss: 0.5829 - val_accuracy: 0.7781 - val_loss: 0.5409
# Epoch 10/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7640 - loss: 0.5606
# Epoch 10: val_accuracy improved from 0.77809 to 0.79232, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.7640 - loss: 0.5606 - val_accuracy: 0.7923 - val_loss: 0.5188
# Epoch 11/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0
50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9217 - loss: 0.2196
# Epoch 40: val_accuracy improved from 0.90560 to 0.91086, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 170s 367ms/step - accuracy: 0.9217 - loss: 0.2196 - val_accuracy: 0.9109 - val_loss: 0.2385
# Epoch 41/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9246 - loss: 0.2126
# Epoch 41: val_accuracy did not improve from 0.91086
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 100s 213ms/step - accuracy: 0.9246 - loss: 0.2126 - val_accuracy: 0.9084 - val_loss: 0.2405
# Epoch 42/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9248 - loss: 0.2078
# Epoch 42: val_accuracy improved from 0.91086 to 0.91272, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9248 - loss: 0.2078 - val_accuracy: 0.9127 - val_loss: 0.2306
# Epoch 43/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9265 - loss: 0.2057
# Epoch 43: val_accuracy improved from 0.91272 to 0.91551, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 101s 217ms/step - accuracy: 0.9265 - loss: 0.2057 - val_accuracy: 0.9155 - val_loss: 0.2279
# Epoch 44/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9288 - loss: 0.1974
# Epoch 44: val_accuracy did not improve from 0.91551
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 101s 217ms/step - accuracy: 0.9288 - loss: 0.1974 - val_accuracy: 0.9136 - val_loss: 0.2283
# Epoch 45/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9332 - loss: 0.1902
# Epoch 45: val_accuracy did not improve from 0.91551
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 111s 237ms/step - accuracy: 0.9332 - loss: 0.1902 - val_accuracy: 0.9106 - val_loss: 0.2352
# Epoch 46/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9356 - loss: 0.1866
# Epoch 46: val_accuracy improved from 0.91551 to 0.92139, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 119s 247ms/step - accuracy: 0.9356 - loss: 0.1866 - val_accuracy: 0.9214 - val_loss: 0.2166
# Epoch 47/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9366 - loss: 0.1830
# Epoch 47: val_accuracy did not improve from 0.92139
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 111s 231ms/step - accuracy: 0.9366 - loss: 0.1830 - val_accuracy: 0.9195 - val_loss: 0.2146
# Epoch 48/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9365 - loss: 0.1770
# Epoch 48: val_accuracy did not improve from 0.92139
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 110s 230ms/step - accuracy: 0.9365 - loss: 0.1770 - val_accuracy: 0.9099 - val_loss: 0.2278
# Epoch 49/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9382 - loss: 0.1729
# Epoch 49: val_accuracy did not improve from 0.92139
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 112s 236ms/step - accuracy: 0.9382 - loss: 0.1729 - val_accuracy: 0.9208 - val_loss: 0.2093
# Epoch 50/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9411 - loss: 0.1669
# Epoch 50: val_accuracy improved from 0.92139 to 0.92696, saving model to /kaggle/working/best_resnet50_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 224ms/step - accuracy: 0.9411 - loss: 0.1669 - val_accuracy: 0.9270 - val_loss: 0.2010
# Restoring model weights from the end of the best epoch: 50.
#
# 📊 Generating Training Curves for Fold 1...
#
# 🔍 Evaluating on unseen Pure Test Set...
#
# 📊 Generating Confusion Matrix for Fold 1...
# ✅ Fold 1 | Acc: 92.92% | F1: 0.9290 | Precision: 0.9292 | Recall: 0.9292
# 🧹 Wiping GPU Memory clean for the next fold...
#
# ==================================================
# 🧪 STARTING FOLD 2 / 5
# ==================================================
#
# ⏳ Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 4 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.4281 - loss: 1.2917
# Epoch 1: val_accuracy improved from -inf to 0.62581, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 115s 229ms/step - accuracy: 0.4283 - loss: 1.2913 - val_accuracy: 0.6258 - val_loss: 0.8671
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0
saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 107s 220ms/step - accuracy: 0.8977 - loss: 0.2784 - val_accuracy: 0.8864 - val_loss: 0.3004
# Epoch 31/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9071 - loss: 0.2616
# Epoch 31: val_accuracy improved from 0.88641 to 0.88982, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 97s 203ms/step - accuracy: 0.9071 - loss: 0.2616 - val_accuracy: 0.8898 - val_loss: 0.2935
# Epoch 32/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9055 - loss: 0.2608
# Epoch 32: val_accuracy did not improve from 0.88982
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 100s 208ms/step - accuracy: 0.9055 - loss: 0.2608 - val_accuracy: 0.8852 - val_loss: 0.2969
# Epoch 33/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9056 - loss: 0.2532
# Epoch 33: val_accuracy improved from 0.88982 to 0.89570, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 99s 209ms/step - accuracy: 0.9056 - loss: 0.2532 - val_accuracy: 0.8957 - val_loss: 0.2820
# Epoch 34/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9138 - loss: 0.2422
# Epoch 34: val_accuracy did not improve from 0.89570
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 102s 214ms/step - accuracy: 0.9138 - loss: 0.2422 - val_accuracy: 0.8957 - val_loss: 0.2783
# Epoch 35/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9128 - loss: 0.2371
# Epoch 35: val_accuracy did not improve from 0.89570
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 109s 230ms/step - accuracy: 0.9128 - loss: 0.2371 - val_accuracy: 0.8935 - val_loss: 0.2747
# Epoch 36/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9167 - loss: 0.2315
# Epoch 36: val_accuracy improved from 0.89570 to 0.90313, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 110s 227ms/step - accuracy: 0.9167 - loss: 0.2315 - val_accuracy: 0.9031 - val_loss: 0.2641
# Epoch 37/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9177 - loss: 0.2275
# Epoch 37: val_accuracy did not improve from 0.90313
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 97s 203ms/step - accuracy: 0.9177 - loss: 0.2275 - val_accuracy: 0.9028 - val_loss: 0.2630
# Epoch 38/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9215 - loss: 0.2204
# Epoch 38: val_accuracy improved from 0.90313 to 0.90529, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 224ms/step - accuracy: 0.9215 - loss: 0.2204 - val_accuracy: 0.9053 - val_loss: 0.2537
# Epoch 39/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9249 - loss: 0.2125
# Epoch 39: val_accuracy improved from 0.90529 to 0.90963, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 97s 204ms/step - accuracy: 0.9249 - loss: 0.2125 - val_accuracy: 0.9096 - val_loss: 0.2554
# Epoch 40/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9278 - loss: 0.2042
# Epoch 40: val_accuracy did not improve from 0.90963
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 100s 211ms/step - accuracy: 0.9278 - loss: 0.2042 - val_accuracy: 0.9047 - val_loss: 0.2524
# Epoch 41/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9304 - loss: 0.1981
# Epoch 41: val_accuracy improved from 0.90963 to 0.91241, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 99s 208ms/step - accuracy: 0.9304 - loss: 0.1981 - val_accuracy: 0.9124 - val_loss: 0.2482
# Epoch 42/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9328 - loss: 0.1919
# Epoch 42: val_accuracy improved from 0.91241 to 0.91458, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 97s 204ms/step - accuracy: 0.9328 - loss: 0.1919 - val_accuracy: 0.9146 - val_loss: 0.2448
# Epoch 43/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9363 - loss: 0.1873
# Epoch 43: val_accuracy improved from 0.91458 to 0.91922, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 105s 221ms/step - accuracy: 0.9363 - loss: 0.1873 - val_accuracy: 0.9192 - val_loss: 0.2317
# Epoch 44/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9367 - loss: 0.1815
# Epoch 44: val_accuracy did not improve from 0.91922
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 102s 214ms/step - accuracy: 0.9367 - loss: 0.1815 - val_accuracy: 0.9127 - val_loss: 0.2382
# Epoch 45/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9369 - loss: 0.1816
# Epoch 45: val_accuracy did not improve from 0.91922
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 96s 203ms/step - accuracy: 0.9369 - loss: 0.1816 - val_accuracy: 0.9180 - val_loss: 0.2262
# Epoch 46/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9394 - loss: 0.1765
# Epoch 46: val_accuracy improved from 0.91922 to 0.92170, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 103s 218ms/step - accuracy: 0.9394 - loss: 0.1765 - val_accuracy: 0.9217 - val_loss: 0.2191
# Epoch 47/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9424 - loss: 0.1686
# Epoch 47: val_accuracy did not improve from 0.92170
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 96s 206ms/step - accuracy: 0.9424 - loss: 0.1686 - val_accuracy: 0.9143 - val_loss: 0.2311
# Epoch 48/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9432 - loss: 0.1679
# Epoch 48: val_accuracy did not improve from 0.92170
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 98s 207ms/step - accuracy: 0.9432 - loss: 0.1679 - val_accuracy: 0.9195 - val_loss: 0.2171
# Epoch 49/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9439 - loss: 0.1653
# Epoch 49: val_accuracy did not improve from 0.92170
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 98s 206ms/step - accuracy: 0.9439 - loss: 0.1653 - val_accuracy: 0.9214 - val_loss: 0.2177
# Epoch 50/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9442 - loss: 0.1617
# Epoch 50: val_accuracy improved from 0.92170 to 0.92293, saving model to /kaggle/working/best_resnet50_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 100s 208ms/step - accuracy: 0.9442 - loss: 0.1617 - val_accuracy: 0.9229 - val_loss: 0.2167
# Restoring model weights from the end of the best epoch: 50.
#
# 📊 Generating Training Curves for Fold 2...
#
# 🔍 Evaluating on unseen Pure Test Set...
#
# 📊 Generating Confusion Matrix for Fold 2...
# ✅ Fold 2 | Acc: 92.93% | F1: 0.9291 | Precision: 0.9301 | Recall: 0.9293
# 🧹 Wiping GPU Memory clean for the next fold...
#
# ==================================================
# 🧪 STARTING FOLD 3 / 5
# ==================================================
#
# ⏳ Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 4 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.4360 - loss: 1.2787
# Epoch 1: val_accuracy improved from -inf to 0.62829, saving model to /kaggle/working/best_resnet50_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 117s 233ms/step - accuracy: 0.4361 - loss: 1.2783 - val_accuracy: 0.6283 - val_loss: 0.8827
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.5936 - loss: 0.9096
# Epoch 2: val_accuracy improved from 0.62829 to 0.65924, saving model to /kaggle/working/best_resnet50_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 107s 227ms/step - accuracy: 0.5936 - loss: 0.9095 - val_accuracy: 0.6592 - val_loss: 0.7846
# Epoch 3/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.6446 - loss: 0.8138
# Epoch 3: val_accuracy improved from 0.65924 to 0.68369, saving model to /kaggle/working/best_resnet50_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 113s 236ms/step - accuracy: 0.6446 - loss: 0.8137 - val_accuracy: 0.6837 - val_loss: 0.7239
# Epoch 4/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.6669 - loss: 0.7550
# Epoch 4: val_accuracy improved from 0.68369 to 0.70535, saving model to /kaggle/working/best_resnet50_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 111s 236ms/step - accuracy: 0.6670 - loss: 0.7549 - val_accuracy: 0.7054 - val_loss: 0.6786
# Epoch 5/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.6892 - loss: 0.7112
# Epoch 5: val_accuracy improved from 0.70535 to 0.72640, saving model to /kaggle/working/best_resnet50_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 112s 239ms/step - accuracy: 0.6892 - loss: 0.7111 - val_accuracy: 0.7264 - val_loss: 0.6556
# Epoch 6/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7042 - loss: 0.6750
# Epoch 6: val_accuracy improved from 0.72640 to 0.74868, saving model to /kaggle/working/best_resnet50_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 109s
saving model to /kaggle/working/best_resnet50_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 111s 234ms/step - accuracy: 0.9065 - loss: 0.2513 - val_accuracy: 0.9136 - val_loss: 0.2503
# Epoch 36/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9117 - loss: 0.2426
# Epoch 36: val_accuracy did not improve from 0.91365
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 110s 234ms/step - accuracy: 0.9117 - loss: 0.2426 - val_accuracy: 0.9102 - val_loss: 0.2515
# Epoch 37/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9119 - loss: 0.2400
# Epoch 37: val_accuracy improved from 0.91365 to 0.91953, saving model to /kaggle/working/best_resnet50_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 113s 240ms/step - accuracy: 0.9119 - loss: 0.2400 - val_accuracy: 0.9195 - val_loss: 0.2372
# Epoch 38/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9138 - loss: 0.2343
# Epoch 38: val_accuracy did not improve from 0.91953
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 227ms/step - accuracy: 0.9138 - loss: 0.2343 - val_accuracy: 0.9121 - val_loss: 0.2455
# Epoch 39/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9159 - loss: 0.2294
# Epoch 39: val_accuracy did not improve from 0.91953
# ...
#
# ⏳ Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 4 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.4480 - loss: 1.2331
# Epoch 1: val_accuracy improved from -inf to 0.61777, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 118s 238ms/step - accuracy: 0.4482 - loss: 1.2328 - val_accuracy: 0.6178 - val_loss: 0.8578
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.6037 - loss: 0.8826
# Epoch 2: val_accuracy improved from 0.61777 to 0.67162, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 230ms/step - accuracy: 0.6038 - loss: 0.8825 - val_accuracy: 0.6716 - val_loss: 0.7582
# Epoch 3/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6445 - loss: 0.7903
# Epoch 3: val_accuracy improved from 0.67162 to 0.69359, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 228ms/step - accuracy: 0.6446 - loss: 0.7902 - val_accuracy: 0.6936 - val_loss: 0.7032
# Epoch 4/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.6743 - loss: 0.7343
# Epoch 4: val_accuracy improved from 0.69359 to 0.70876, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 109s 232ms/step - accuracy: 0.6743 - loss: 0.7342 - val_accuracy: 0.7088 - val_loss: 0.6635
# Epoch 5/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7011 - loss: 0.6912
# Epoch 5: val_accuracy improved from 0.70876 to 0.72145, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 107s 228ms/step - accuracy: 0.7010 - loss: 0.6912 - val_accuracy: 0.7214 - val_loss: 0.6375
# Epoch 6/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7131 - loss: 0.6617
# Epoch 6: val_accuracy improved from 0.72145 to 0.72485, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.7131 - loss: 0.6617 - val_accuracy: 0.7249 - val_loss: 0.6160
# Epoch 7/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7287 - loss: 0.6305
# Epoch 7: val_accuracy improved from 0.72485 to 0.74497, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 227ms/step - accuracy: 0.7287 - loss: 0.6305 - val_accuracy: 0.7450 - val_loss: 0.5890
# Epoch 8/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7387 - loss: 0.6050
# Epoch 8: val_accuracy improved from 0.74497 to 0.77314, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 228ms/step - accuracy: 0.7387 - loss: 0.6050 - val_accuracy: 0.7731 - val_loss: 0.5543
# Epoch 9/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7473 - loss: 0.5785
# Epoch 9: val_accuracy improved from 0.77314 to 0.77778, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 231ms/step - accuracy: 0.7473 - loss: 0.5785 - val_accuracy: 0.7778 - val_loss: 0.5351
# Epoch 10/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7678 - loss: 0.5511
# Epoch 10: val_accuracy improved from 0.77778 to 0.78335, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.7678 - loss: 0.5511 - val_accuracy: 0.7833 - val_loss: 0.5195
# Epoch 11/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0
saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 107s 229ms/step - accuracy: 0.8745 - loss: 0.3330 - val_accuracy: 0.8796 - val_loss: 0.3246
# Epoch 26/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8777 - loss: 0.3237
# Epoch 26: val_accuracy improved from 0.87960 to 0.88270, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 228ms/step - accuracy: 0.8777 - loss: 0.3236 - val_accuracy: 0.8827 - val_loss: 0.3142
# Epoch 27/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8749 - loss: 0.3192
# Epoch 27: val_accuracy did not improve from 0.88270
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.8749 - loss: 0.3192 - val_accuracy: 0.8610 - val_loss: 0.3453
# Epoch 28/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8817 - loss: 0.3064
# Epoch 28: val_accuracy improved from 0.88270 to 0.89044, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 231ms/step - accuracy: 0.8817 - loss: 0.3064 - val_accuracy: 0.8904 - val_loss: 0.3017
# Epoch 29/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8918 - loss: 0.2908
# Epoch 29: val_accuracy did not improve from 0.89044
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 229ms/step - accuracy: 0.8918 - loss: 0.2908 - val_accuracy: 0.8836 - val_loss: 0.3040
# Epoch 30/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8935 - loss: 0.2853
# Epoch 30: val_accuracy did not improve from 0.89044
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 225ms/step - accuracy: 0.8935 - loss: 0.2853 - val_accuracy: 0.8821 - val_loss: 0.2950
# Epoch 31/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8962 - loss: 0.2769
# Epoch 31: val_accuracy improved from 0.89044 to 0.89508, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 110s 236ms/step - accuracy: 0.8962 - loss: 0.2769 - val_accuracy: 0.8951 - val_loss: 0.2810
# Epoch 32/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9027 - loss: 0.2681
# Epoch 32: val_accuracy improved from 0.89508 to 0.90096, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.9027 - loss: 0.2681 - val_accuracy: 0.9010 - val_loss: 0.2731
# Epoch 33/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9031 - loss: 0.2606
# Epoch 33: val_accuracy did not improve from 0.90096
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 229ms/step - accuracy: 0.9031 - loss: 0.2606 - val_accuracy: 0.8982 - val_loss: 0.2767
# Epoch 34/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9092 - loss: 0.2529
# Epoch 34: val_accuracy improved from 0.90096 to 0.90591, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 231ms/step - accuracy: 0.9092 - loss: 0.2529 - val_accuracy: 0.9059 - val_loss: 0.2584
# Epoch 35/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9090 - loss: 0.2469
# Epoch 35: val_accuracy did not improve from 0.90591
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.9090 - loss: 0.2469 - val_accuracy: 0.9037 - val_loss: 0.2582
# Epoch 36/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9078 - loss: 0.2495
# Epoch 36: val_accuracy improved from 0.90591 to 0.91148, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 107s 226ms/step - accuracy: 0.9078 - loss: 0.2495 - val_accuracy: 0.9115 - val_loss: 0.2496
# Epoch 37/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9148 - loss: 0.2392
# Epoch 37: val_accuracy did not improve from 0.91148
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 107s 228ms/step - accuracy: 0.9148 - loss: 0.2392 - val_accuracy: 0.9081 - val_loss: 0.2461
# Epoch 38/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9149 - loss: 0.2289
# Epoch 38: val_accuracy improved from 0.91148 to 0.91179, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 233ms/step - accuracy: 0.9149 - loss: 0.2289 - val_accuracy: 0.9118 - val_loss: 0.2409
# Epoch 39/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9185 - loss: 0.2304
# Epoch 39: val_accuracy improved from 0.91179 to 0.91241, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 232ms/step - accuracy: 0.9185 - loss: 0.2304 - val_accuracy: 0.9124 - val_loss: 0.2424
# Epoch 40/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9197 - loss: 0.2216
# Epoch 40: val_accuracy improved from 0.91241 to 0.91365, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 233ms/step - accuracy: 0.9197 - loss: 0.2216 - val_accuracy: 0.9136 - val_loss: 0.2391
# Epoch 41/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9221 - loss: 0.2198
# Epoch 41: val_accuracy did not improve from 0.91365
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 227ms/step - accuracy: 0.9221 - loss: 0.2198 - val_accuracy: 0.9115 - val_loss: 0.2323
# Epoch 42/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9246 - loss: 0.2073
# Epoch 42: val_accuracy improved from 0.91365 to 0.92046, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 232ms/step - accuracy: 0.9246 - loss: 0.2073 - val_accuracy: 0.9205 - val_loss: 0.2247
# Epoch 43/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9310 - loss: 0.2009
# Epoch 43: val_accuracy did not improve from 0.92046
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 111s 237ms/step - accuracy: 0.9310 - loss: 0.2009 - val_accuracy: 0.9186 - val_loss: 0.2196
# Epoch 44/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9320 - loss: 0.1963
# Epoch 44: val_accuracy did not improve from 0.92046
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.9320 - loss: 0.1963 - val_accuracy: 0.9180 - val_loss: 0.2221
# Epoch 45/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9322 - loss: 0.1886
# Epoch 45: val_accuracy did not improve from 0.92046
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 227ms/step - accuracy: 0.9322 - loss: 0.1886 - val_accuracy: 0.9174 - val_loss: 0.2152
# Epoch 46/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9315 - loss: 0.1904
# Epoch 46: val_accuracy improved from 0.92046 to 0.92293, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 228ms/step - accuracy: 0.9315 - loss: 0.1904 - val_accuracy: 0.9229 - val_loss: 0.2108
# Epoch 47/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9368 - loss: 0.1816
# Epoch 47: val_accuracy did not improve from 0.92293
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 105s 226ms/step - accuracy: 0.9368 - loss: 0.1816 - val_accuracy: 0.9174 - val_loss: 0.2132
# Epoch 48/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9363 - loss: 0.1774
# Epoch 48: val_accuracy improved from 0.92293 to 0.92789, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 107s 229ms/step - accuracy: 0.9363 - loss: 0.1774 - val_accuracy: 0.9279 - val_loss: 0.2102
# Epoch 49/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9380 - loss: 0.1748
# Epoch 49: val_accuracy improved from 0.92789 to 0.93129, saving model to /kaggle/working/best_resnet50_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 108s 230ms/step - accuracy: 0.9380 - loss: 0.1748 - val_accuracy: 0.9313 - val_loss: 0.2053
# Epoch 50/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9413 - loss: 0.1709
# Epoch 50: val_accuracy did not improve from 0.93129
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 106s 222ms/step - accuracy: 0.9413 - loss: 0.1709 - val_accuracy: 0.9304 - val_loss: 0.1943
# Restoring model weights from the end of the best epoch: 49.
#
# 📊 Generating Training Curves for Fold 5...
#
# 🔍 Evaluating on unseen Pure Test Set...
#
# 📊 Generating Confusion Matrix for Fold 5...
# ✅ Fold 5 | Acc: 92.86% | F1: 0.9286 | Precision: 0.9294 | Recall: 0.9286
# 🧹 Wiping GPU Memory clean for the next fold...
#
# 🎉 ALL 5 FOLDS COMPLETE!
# 🏆 Avg Accuracy  : 92.87% (+/- 0.06%)
# 🏆 Avg F1 Score  : 0.9287 (+/- 0.0006)
# 🏆 Avg Precision : 0.9292 (+/- 0.0007)
# 🏆 Avg Recall    : 0.9287 (+/- 0.0006)
# ⏱️ Total Experiment Time: 454.40 minutes
