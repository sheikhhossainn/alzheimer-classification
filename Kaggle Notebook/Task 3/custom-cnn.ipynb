# %%
import os
import random
import time
import gc
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Activation, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix


SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)


if 'strategy' not in locals():
    try:
        strategy = tf.distribute.MirroredStrategy()
        print(f" Dual-GPU Strategy Initialized. Replicas: {strategy.num_replicas_in_sync}")
    except Exception as e:
        print(f" GPU initialization failed: {e}")
        strategy = tf.distribute.get_strategy()
else:
    print(f" Strategy already active. Replicas: {strategy.num_replicas_in_sync}")

BATCH_SIZE = 32 * strategy.num_replicas_in_sync
AUTOTUNE = tf.data.AUTOTUNE


DATA_DIR = '/kaggle/input/datasets/uraninjo/augmented-alzheimer-mri-dataset-v2'
print("\nFetching Local File Paths...")
filepaths = []

for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            filepaths.append(os.path.join(root, file))

filepaths.sort() 

labels = [os.path.basename(os.path.dirname(path)) for path in filepaths]
df = pd.DataFrame({'filepath': filepaths, 'label': labels})
class_names = sorted(df['label'].unique())
class_indices = {name: idx for idx, name in enumerate(class_names)}
df['label_idx'] = df['label'].map(class_indices)

print(f" Successfully pooled and sorted {len(df)} images.")
print(f"Classes found: {class_indices}")


def decode_image(filepath, label):
    image_bytes = tf.io.read_file(filepath)
    image = tf.io.decode_image(image_bytes, channels=3, expand_animations=False)
    image = tf.image.resize(image, [224, 224])
    
    image = image / 255.0 
    
    label = tf.one_hot(label, depth=len(class_names))
    return image, label

def decode_image_predict_only(filepath):
    image_bytes = tf.io.read_file(filepath)
    image = tf.io.decode_image(image_bytes, channels=3, expand_animations=False)
    image = tf.image.resize(image, [224, 224])
    image = image / 255.0
    return image

def build_dataset(dataframe, is_training=False):
    dataset = tf.data.Dataset.from_tensor_slices((dataframe['filepath'].values, dataframe['label_idx'].values))
    dataset = dataset.map(decode_image, num_parallel_calls=AUTOTUNE)
    if is_training:
        dataset = dataset.shuffle(buffer_size=2048, seed=SEED)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return dataset

def build_predict_dataset(dataframe):
    dataset = tf.data.Dataset.from_tensor_slices(dataframe['filepath'].values)
    dataset = dataset.map(decode_image_predict_only, num_parallel_calls=AUTOTUNE, deterministic=True)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return dataset

# CUSTOM CNN ARCHITECTURE

def build_custom_cnn_model():
    tf.keras.backend.clear_session()
    with strategy.scope():
        inputs = Input(shape=(224, 224, 3))
        
        # Block 1
        x = Conv2D(32, (3, 3), padding='same')(inputs)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        
        # Block 2
        x = Conv2D(64, (3, 3), padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        
        # Block 3
        x = Conv2D(128, (3, 3), padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        
        # Block 4
        x = Conv2D(256, (3, 3), padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        
        # Top Layers
        x = GlobalAveragePooling2D()(x)
        x = Dense(256, activation='relu')(x)
        x = Dropout(0.5)(x)
        outputs = Dense(len(class_names), activation='softmax')(x)
        
        model = Model(inputs=inputs, outputs=outputs)
        
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
    return model


K_FOLDS = 5
EPOCHS = 50

skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

fold_accuracies    = []
fold_f1_scores     = []
fold_precisions    = []
fold_recalls       = []
fold_conf_matrices = []

print("\n STARTING 5-FOLD CROSS-VALIDATION (Custom CNN on T4 x2 GPUs)...")
start_time = time.time()

for fold, (train_val_idx, test_idx) in enumerate(skf.split(df['filepath'], df['label_idx'])):
    fold_num = fold + 1
    print(f"\n{'='*50}\n STARTING FOLD {fold_num} / {K_FOLDS}\n{'='*50}")

    test_df      = df.iloc[test_idx]
    train_val_df = df.iloc[train_val_idx]
    
    train_df, val_df = train_test_split(
        train_val_df, test_size=0.1,
        stratify=train_val_df['label_idx'], random_state=SEED
    )

    train_ds   = build_dataset(train_df, is_training=True)
    val_ds     = build_dataset(val_df, is_training=False)
    test_ds    = build_dataset(test_df, is_training=False)
    predict_ds = build_predict_dataset(test_df)

    model = build_custom_cnn_model()

    checkpoint_path = f'/kaggle/working/best_customcnn_fold_{fold_num}.keras'
    checkpoint      = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
    early_stopping  = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1)

    print("\n Training Model...")
    history = model.fit(
        train_ds, validation_data=val_ds,
        epochs=EPOCHS, callbacks=[checkpoint, early_stopping], verbose=1
    )

    print(f"\n Generating Training Curves for Fold {fold_num}...")
    plt.figure(figsize=(14, 5))
    
    # Plotting accuracy curve
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    plt.title(f'Fold {fold_num}: Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.7)

    # Plotting loss curve
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
    plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    plt.title(f'Fold {fold_num}: Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()  

    print("\n Evaluating on unseen Pure Test Set...")
    model.load_weights(checkpoint_path)

    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    fold_accuracies.append(test_acc)

    true_labels = test_df['label_idx'].values
    pred_probs  = model.predict(predict_ds, verbose=0)
    pred_labels = np.argmax(pred_probs, axis=1)

    f1   = f1_score(true_labels, pred_labels, average='weighted')
    prec = precision_score(true_labels, pred_labels, average='weighted')
    rec  = recall_score(true_labels, pred_labels, average='weighted')
    cm   = confusion_matrix(true_labels, pred_labels)

    fold_f1_scores.append(f1)
    fold_precisions.append(prec)
    fold_recalls.append(rec)
    fold_conf_matrices.append(cm)

    print(f"\n Generating Confusion Matrix for Fold {fold_num}...")
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Fold {fold_num}: Custom CNN Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.tight_layout()
    plt.show()  

    print(f" Fold {fold_num} | Acc: {test_acc*100:.2f}% | F1: {f1:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f}")

    print(" Wiping GPU Memory clean for the next fold...")
    del model, train_ds, val_ds, test_ds, predict_ds, history
    tf.keras.backend.clear_session()
    gc.collect()


np.save('/kaggle/working/CustomCNN_5Fold_Accuracies_DualGPU.npy',  np.array(fold_accuracies))
np.save('/kaggle/working/CustomCNN_5Fold_F1_DualGPU.npy',          np.array(fold_f1_scores))
np.save('/kaggle/working/CustomCNN_5Fold_Precision_DualGPU.npy',   np.array(fold_precisions))
np.save('/kaggle/working/CustomCNN_5Fold_Recall_DualGPU.npy',      np.array(fold_recalls))
np.save('/kaggle/working/CustomCNN_5Fold_ConfMatrix_DualGPU.npy',  np.array(fold_conf_matrices))

print(f"\n ALL {K_FOLDS} FOLDS COMPLETE!")
print(f" Avg Accuracy  : {np.mean(fold_accuracies)*100:.2f}% (+/- {np.std(fold_accuracies)*100:.2f}%)")
print(f" Avg F1 Score  : {np.mean(fold_f1_scores):.4f} (+/- {np.std(fold_f1_scores):.4f})")
print(f" Avg Precision : {np.mean(fold_precisions):.4f} (+/- {np.std(fold_precisions):.4f})")
print(f" Avg Recall    : {np.mean(fold_recalls):.4f} (+/- {np.std(fold_recalls):.4f})")
print(f" Total Experiment Time: {(time.time() - start_time) / 60:.2f} minutes")
# Out:
# 2026-04-24 17:02:46.145789: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777050166.386995      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777050166.453890      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777050166.994424      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777050166.994472      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777050166.994475      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777050166.994477      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# I0000 00:00:1777050196.024858      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777050196.030888      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
#  Dual-GPU Strategy Initialized. Replicas: 2
#
# Fetching Local File Paths...
#  Successfully pooled and sorted 40384 images.
# Classes found: {'MildDemented': 0, 'ModerateDemented': 1, 'NonDemented': 2, 'VeryMildDemented': 3}
#
#  STARTING 5-FOLD CROSS-VALIDATION (Custom CNN on T4 x2 GPUs)...
#
# ==================================================
#  STARTING FOLD 1 / 5
# ==================================================
#
#  Training Model...
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 20 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# I0000 00:00:1777050296.244699      69 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1777050296.254621      70 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.3909 - loss: 1.2963INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_accuracy improved from -inf to 0.31972, saving model to /kaggle/working/best_customcnn_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 100s 198ms/step - accuracy: 0.3911 - loss: 1.2960 - val_accuracy: 0.3197 - val_loss: 1.5593
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5242 - loss: 1.0292
# Epoch 2: val_accuracy improved from 0.31972 to 0.49180, saving model to /kaggle/working/best_customcnn_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.5243 - loss: 1.0291 - val_accuracy: 0.4918 - val_loss: 1.0309
# Epoch 3/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.5723 - loss: 0.9226
# Epoch 3: val_accuracy improved from 0.49180 to 0.59455, saving model to /kaggle/working/best_customcnn_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.5723 - loss: 0.9225 - val_accuracy: 0.5946 - val_loss: 0.8606
# Epoch 4/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.6146 - loss: 0.8351
# Epoch 4: val_accuracy did not improve from 0.59455
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.6146 - loss: 0.8350 - val_accuracy: 0.2847 - val_loss: 2.2916
# Epoch 5/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6427 - loss: 0.7882
# Epoch 5: val_accuracy did not improve from 0.59455
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.6428 - loss: 0.7882 - val_accuracy: 0.5172 - val_loss: 0.9513
# Epoch 6/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6572 - loss: 0.7456
# Epoch 6: val_accuracy did not improve from 0.59455
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.6572 - loss: 0.7456 - val_accuracy: 0.5924 - val_loss: 0.8567
# Epoch 7/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6801 - loss: 0.7032
# Epoch 7: val_accuracy did not improve from 0.59455
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 176ms/step - accuracy: 0.6801 - loss: 0.7032 - val_accuracy: 0.3717 - val_loss: 1.9702
# Epoch 8/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7016 - loss: 0.6684
# Epoch 8: val_accuracy improved from 0.59455 to 0.62365, saving model to /kaggle/working/best_customcnn_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 179ms/step - accuracy: 0.7016 - loss: 0.6683 - val_accuracy: 0.6236 - val_loss: 0.8469
# Epoch 9/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7203 - loss: 0.6337
# Epoch 9: val_accuracy improved from 0.62365 to 0.68059, saving model to /kaggle/working/best_customcnn_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.7203 - loss: 0.6336 - val_accuracy: 0.6806 - val_loss: 0.6847
# Epoch 10/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7386 - loss: 0.5954
# Epoch 10: val_accuracy did not improve from 0.68059
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.7386 - loss: 0.5954 - val_accuracy: 0.6029 - val_loss: 0.9426
# Epoch 11/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7633 - loss: 0.5556
# Epoch 11: val_accuracy did not improve from 0.68059
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.7633 - loss: 0.5556 - val_accuracy: 0.2476 - val_loss: 3.2811
# Epoch 12/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7842 - loss: 0.5191
# Epoch 12: val_accuracy did not improve from 0.68059
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.7842 - loss: 0.5191 - val_accuracy: 0.2470 - val_loss: 3.2460
# Epoch 13/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7922 - loss: 0.4978
# Epoch 13: val_accuracy did not improve from 0.68059
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.7922 - loss: 0.4978 - val_accuracy: 0.4763 - val_loss: 1.7043
# Epoch 14/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8135 - loss: 0.4538
# Epoch 14: val_accuracy did not improve from 0.68059
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8135 - loss: 0.4538 - val_accuracy: 0.4336 - val_loss: 1.8802
# Epoch 15/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8264 - loss: 0.4347
# Epoch 15: val_accuracy did not improve from 0.68059
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.8264 - loss: 0.4347 - val_accuracy: 0.5682 - val_loss: 1.2053
# Epoch 16/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8362 - loss: 0.4040
# Epoch 16: val_accuracy did not improve from 0.68059
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8362 - loss: 0.4040 - val_accuracy: 0.6515 - val_loss: 0.7605
# Epoch 17/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8523 - loss: 0.3654
# Epoch 17: val_accuracy improved from 0.68059 to 0.79140, saving model to /kaggle/working/best_customcnn_fold_1.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8523 - loss: 0.3654 - val_accuracy: 0.7914 - val_loss: 0.4624
# Epoch 18/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8619 - loss: 0.3497
# Epoch 18: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.8619 - loss: 0.3497 - val_accuracy: 0.3299 - val_loss: 2.2700
# Epoch 19/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8739 - loss: 0.3265
# Epoch 19: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 179ms/step - accuracy: 0.8739 - loss: 0.3265 - val_accuracy: 0.6351 - val_loss: 1.0255
# Epoch 20/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8833 - loss: 0.3075
# Epoch 20: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8833 - loss: 0.3075 - val_accuracy: 0.5484 - val_loss: 1.3728
# Epoch 21/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8917 - loss: 0.2887
# Epoch 21: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8917 - loss: 0.2887 - val_accuracy: 0.4565 - val_loss: 3.3386
# Epoch 22/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8991 - loss: 0.2606
# Epoch 22: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8991 - loss: 0.2606 - val_accuracy: 0.5370 - val_loss: 2.5840
# Epoch 23/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9062 - loss: 0.2519
# Epoch 23: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.9062 - loss: 0.2519 - val_accuracy: 0.4497 - val_loss: 2.9274
# Epoch 24/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9156 - loss: 0.2271
# Epoch 24: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.9156 - loss: 0.2271 - val_accuracy: 0.6496 - val_loss: 1.0964
# Epoch 25/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9187 - loss: 0.2214
# Epoch 25: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.9187 - loss: 0.2213 - val_accuracy: 0.4859 - val_loss: 2.9772
# Epoch 26/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9313 - loss: 0.1903
# Epoch 26: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.9313 - loss: 0.1903 - val_accuracy: 0.3739 - val_loss: 5.6051
# Epoch 27/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9328 - loss: 0.1846
# Epoch 27: val_accuracy did not improve from 0.79140
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.9328 - loss: 0.1846 - val_accuracy: 0.6289 - val_loss: 1.0788
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
#  Generating Training Curves for Fold 1...
#  Evaluating on unseen Pure Test Set...
#
#  Generating Confusion Matrix for Fold 1...
#  Fold 1 | Acc: 78.57% | F1: 0.7611 | Precision: 0.8251 | Recall: 0.7857
#  Wiping GPU Memory clean for the next fold...
#
# ==================================================
#  STARTING FOLD 2 / 5
# ==================================================
#
#  Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 20 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.3858 - loss: 1.3191
# Epoch 1: val_accuracy improved from -inf to 0.16156, saving model to /kaggle/working/best_customcnn_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 85s 176ms/step - accuracy: 0.3859 - loss: 1.3188 - val_accuracy: 0.1616 - val_loss: 2.2990
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.4981 - loss: 1.0658
# Epoch 2: val_accuracy improved from 0.16156 to 0.46518, saving model to /kaggle/working/best_customcnn_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.4982 - loss: 1.0657 - val_accuracy: 0.4652 - val_loss: 1.0455
# Epoch 3/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5593 - loss: 0.9569
# Epoch 3: val_accuracy did not improve from 0.46518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.5593 - loss: 0.9568 - val_accuracy: 0.4633 - val_loss: 1.3611
# Epoch 4/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.6031 - loss: 0.8644
# Epoch 4: val_accuracy did not improve from 0.46518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.6031 - loss: 0.8644 - val_accuracy: 0.4290 - val_loss: 1.5183
# Epoch 5/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6219 - loss: 0.8154
# Epoch 5: val_accuracy improved from 0.46518 to 0.66636, saving model to /kaggle/working/best_customcnn_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.6220 - loss: 0.8154 - val_accuracy: 0.6664 - val_loss: 0.7320
# Epoch 6/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.6469 - loss: 0.7690
# Epoch 6: val_accuracy did not improve from 0.66636
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.6469 - loss: 0.7690 - val_accuracy: 0.5370 - val_loss: 0.9099
# Epoch 7/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6629 - loss: 0.7324
# Epoch 7: val_accuracy did not improve from 0.66636
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.6629 - loss: 0.7324 - val_accuracy: 0.5286 - val_loss: 1.1294
# Epoch 8/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6851 - loss: 0.6986
# Epoch 8: val_accuracy did not improve from 0.66636
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 176ms/step - accuracy: 0.6851 - loss: 0.6986 - val_accuracy: 0.5330 - val_loss: 1.1284
# Epoch 9/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7018 - loss: 0.6685
# Epoch 9: val_accuracy did not improve from 0.66636
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.7018 - loss: 0.6685 - val_accuracy: 0.4574 - val_loss: 2.9405
# Epoch 10/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7243 - loss: 0.6280
# Epoch 10: val_accuracy improved from 0.66636 to 0.68833, saving model to /kaggle/working/best_customcnn_fold_2.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.7243 - loss: 0.6280 - val_accuracy: 0.6883 - val_loss: 0.6593
# Epoch 11/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7469 - loss: 0.5835
# Epoch 11: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.7469 - loss: 0.5835 - val_accuracy: 0.3863 - val_loss: 2.2482
# Epoch 12/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7659 - loss: 0.5512
# Epoch 12: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 80s 173ms/step - accuracy: 0.7660 - loss: 0.5511 - val_accuracy: 0.5816 - val_loss: 1.0877
# Epoch 13/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7856 - loss: 0.5165
# Epoch 13: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 176ms/step - accuracy: 0.7856 - loss: 0.5165 - val_accuracy: 0.5150 - val_loss: 1.3200
# Epoch 14/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7995 - loss: 0.4901
# Epoch 14: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.7995 - loss: 0.4900 - val_accuracy: 0.5946 - val_loss: 0.9058
# Epoch 15/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8192 - loss: 0.4447
# Epoch 15: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.8192 - loss: 0.4447 - val_accuracy: 0.6097 - val_loss: 0.8859
# Epoch 16/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8297 - loss: 0.4279
# Epoch 16: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.8298 - loss: 0.4278 - val_accuracy: 0.5806 - val_loss: 1.0729
# Epoch 17/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8448 - loss: 0.3951
# Epoch 17: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.8448 - loss: 0.3950 - val_accuracy: 0.5670 - val_loss: 1.1472
# Epoch 18/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8537 - loss: 0.3691
# Epoch 18: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.8537 - loss: 0.3690 - val_accuracy: 0.3847 - val_loss: 2.1251
# Epoch 19/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8638 - loss: 0.3525
# Epoch 19: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.8638 - loss: 0.3525 - val_accuracy: 0.6097 - val_loss: 1.0758
# Epoch 20/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8769 - loss: 0.3253
# Epoch 20: val_accuracy did not improve from 0.68833
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.8770 - loss: 0.3252 - val_accuracy: 0.2956 - val_loss: 3.1714
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
#  Generating Training Curves for Fold 2...
#  Evaluating on unseen Pure Test Set...
#
#  Generating Confusion Matrix for Fold 2...
#  Fold 2 | Acc: 68.55% | F1: 0.6676 | Precision: 0.7259 | Recall: 0.6855
#  Wiping GPU Memory clean for the next fold...
#
# ==================================================
#  STARTING FOLD 3 / 5
# ==================================================
#
#  Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 20 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.4003 - loss: 1.2811
# Epoch 1: val_accuracy improved from -inf to 0.17332, saving model to /kaggle/working/best_customcnn_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 86s 179ms/step - accuracy: 0.4004 - loss: 1.2808 - val_accuracy: 0.1733 - val_loss: 1.9268
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.5065 - loss: 1.0592
# Epoch 2: val_accuracy improved from 0.17332 to 0.45187, saving model to /kaggle/working/best_customcnn_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 177ms/step - accuracy: 0.5065 - loss: 1.0592 - val_accuracy: 0.4519 - val_loss: 1.2694
# Epoch 3/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.5684 - loss: 0.9421
# Epoch 3: val_accuracy did not improve from 0.45187
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.5684 - loss: 0.9420 - val_accuracy: 0.4475 - val_loss: 1.3944
# Epoch 4/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.6067 - loss: 0.8531
# Epoch 4: val_accuracy improved from 0.45187 to 0.57072, saving model to /kaggle/working/best_customcnn_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.6067 - loss: 0.8530 - val_accuracy: 0.5707 - val_loss: 0.9250
# Epoch 5/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6245 - loss: 0.8091
# Epoch 5: val_accuracy did not improve from 0.57072
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.6245 - loss: 0.8090 - val_accuracy: 0.3742 - val_loss: 1.7561
# Epoch 6/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6540 - loss: 0.7584
# Epoch 6: val_accuracy did not improve from 0.57072
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 178ms/step - accuracy: 0.6541 - loss: 0.7584 - val_accuracy: 0.5546 - val_loss: 1.0464
# Epoch 7/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6716 - loss: 0.7223
# Epoch 7: val_accuracy improved from 0.57072 to 0.59239, saving model to /kaggle/working/best_customcnn_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.6716 - loss: 0.7223 - val_accuracy: 0.5924 - val_loss: 0.8947
# Epoch 8/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6892 - loss: 0.6897
# Epoch 8: val_accuracy improved from 0.59239 to 0.60074, saving model to /kaggle/working/best_customcnn_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.6892 - loss: 0.6896 - val_accuracy: 0.6007 - val_loss: 0.8629
# Epoch 9/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7129 - loss: 0.6570
# Epoch 9: val_accuracy improved from 0.60074 to 0.66574, saving model to /kaggle/working/best_customcnn_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.7129 - loss: 0.6569 - val_accuracy: 0.6657 - val_loss: 0.7129
# Epoch 10/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7320 - loss: 0.6208
# Epoch 10: val_accuracy did not improve from 0.66574
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.7320 - loss: 0.6208 - val_accuracy: 0.6537 - val_loss: 0.7469
# Epoch 11/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7499 - loss: 0.5787
# Epoch 11: val_accuracy did not improve from 0.66574
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.7499 - loss: 0.5786 - val_accuracy: 0.6416 - val_loss: 1.1564
# Epoch 12/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7690 - loss: 0.5502
# Epoch 12: val_accuracy did not improve from 0.66574
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.7690 - loss: 0.5502 - val_accuracy: 0.3355 - val_loss: 3.0275
# Epoch 13/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7892 - loss: 0.5103
# Epoch 13: val_accuracy improved from 0.66574 to 0.75518, saving model to /kaggle/working/best_customcnn_fold_3.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.7893 - loss: 0.5103 - val_accuracy: 0.7552 - val_loss: 0.5481
# Epoch 14/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7986 - loss: 0.4939
# Epoch 14: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 84s 182ms/step - accuracy: 0.7986 - loss: 0.4939 - val_accuracy: 0.6110 - val_loss: 0.7736
# Epoch 15/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8181 - loss: 0.4501
# Epoch 15: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8181 - loss: 0.4501 - val_accuracy: 0.6320 - val_loss: 1.4342
# Epoch 16/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8300 - loss: 0.4241
# Epoch 16: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.8300 - loss: 0.4241 - val_accuracy: 0.4937 - val_loss: 2.6828
# Epoch 17/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8447 - loss: 0.3939
# Epoch 17: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 177ms/step - accuracy: 0.8447 - loss: 0.3939 - val_accuracy: 0.6261 - val_loss: 1.9753
# Epoch 18/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8538 - loss: 0.3753
# Epoch 18: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 177ms/step - accuracy: 0.8539 - loss: 0.3753 - val_accuracy: 0.4150 - val_loss: 3.3120
# Epoch 19/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8653 - loss: 0.3572
# Epoch 19: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.8653 - loss: 0.3572 - val_accuracy: 0.4735 - val_loss: 3.2698
# Epoch 20/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8722 - loss: 0.3345
# Epoch 20: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8723 - loss: 0.3345 - val_accuracy: 0.4766 - val_loss: 2.3753
# Epoch 21/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8852 - loss: 0.3051
# Epoch 21: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 175ms/step - accuracy: 0.8852 - loss: 0.3051 - val_accuracy: 0.6376 - val_loss: 1.1467
# Epoch 22/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8982 - loss: 0.2773
# Epoch 22: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.8982 - loss: 0.2773 - val_accuracy: 0.4339 - val_loss: 2.1610
# Epoch 23/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8998 - loss: 0.2671
# Epoch 23: val_accuracy did not improve from 0.75518
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.8998 - loss: 0.2671 - val_accuracy: 0.6667 - val_loss: 0.8291
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
#
#  Generating Training Curves for Fold 3...
#  Evaluating on unseen Pure Test Set...
#
#  Generating Confusion Matrix for Fold 3...
#  Fold 3 | Acc: 75.61% | F1: 0.7618 | Precision: 0.8245 | Recall: 0.7561
#  Wiping GPU Memory clean for the next fold...
#
# ==================================================
#  STARTING FOLD 4 / 5
# ==================================================
#
#  Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 20 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.3726 - loss: 1.3230
# Epoch 1: val_accuracy improved from -inf to 0.16156, saving model to /kaggle/working/best_customcnn_fold_4.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 88s 180ms/step - accuracy: 0.3727 - loss: 1.3228 - val_accuracy: 0.1616 - val_loss: 2.7316
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5131 - loss: 1.0534
# Epoch 2: val_accuracy improved from 0.16156 to 0.33829, saving model to /kaggle/working/best_customcnn_fold_4.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 85s 182ms/step - accuracy: 0.5131 - loss: 1.0534 - val_accuracy: 0.3383 - val_loss: 1.9515
# Epoch 3/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.5628 - loss: 0.9497
# Epoch 3: val_accuracy improved from 0.33829 to 0.33983, saving model to /kaggle/working/best_customcnn_fold_4.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 179ms/step - accuracy: 0.5628 - loss: 0.9496 - val_accuracy: 0.3398 - val_loss: 1.5932
# Epoch 4/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6014 - loss: 0.8710
# Epoch 4: val_accuracy improved from 0.33983 to 0.40421, saving model to /kaggle/working/best_customcnn_fold_4.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.6014 - loss: 0.8710 - val_accuracy: 0.4042 - val_loss: 1.3289
# Epoch 5/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.6249 - loss: 0.8101
# Epoch 5: val_accuracy improved from 0.40421 to 0.59455, saving model to /kaggle/working/best_customcnn_fold_4.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 84s 180ms/step - accuracy: 0.6250 - loss: 0.8101 - val_accuracy: 0.5946 - val_loss: 0.8549
# Epoch 6/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.6476 - loss: 0.7694
# Epoch 6: val_accuracy improved from 0.59455 to 0.64191, saving model to /kaggle/working/best_customcnn_fold_4.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 84s 180ms/step - accuracy: 0.6477 - loss: 0.7694 - val_accuracy: 0.6419 - val_loss: 0.8260
# Epoch 7/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.6683 - loss: 0.7314
# Epoch 7: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 84s 179ms/step - accuracy: 0.6683 - loss: 0.7314 - val_accuracy: 0.4680 - val_loss: 1.1000
# Epoch 8/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6751 - loss: 0.7067
# Epoch 8: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.6751 - loss: 0.7067 - val_accuracy: 0.4751 - val_loss: 1.3632
# Epoch 9/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.6990 - loss: 0.6691
# Epoch 9: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.6990 - loss: 0.6690 - val_accuracy: 0.6240 - val_loss: 0.8383
# Epoch 10/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7220 - loss: 0.6229
# Epoch 10: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 179ms/step - accuracy: 0.7220 - loss: 0.6229 - val_accuracy: 0.3370 - val_loss: 1.6518
# Epoch 11/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7424 - loss: 0.5967
# Epoch 11: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 180ms/step - accuracy: 0.7424 - loss: 0.5967 - val_accuracy: 0.4776 - val_loss: 1.6202
# Epoch 12/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7571 - loss: 0.5665
# Epoch 12: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.7572 - loss: 0.5664 - val_accuracy: 0.4896 - val_loss: 2.1875
# Epoch 13/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7750 - loss: 0.5371
# Epoch 13: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 179ms/step - accuracy: 0.7751 - loss: 0.5371 - val_accuracy: 0.4791 - val_loss: 1.1632
# Epoch 14/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7943 - loss: 0.4922
# Epoch 14: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.7943 - loss: 0.4922 - val_accuracy: 0.2937 - val_loss: 3.7365
# Epoch 15/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8164 - loss: 0.4572
# Epoch 15: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 179ms/step - accuracy: 0.8164 - loss: 0.4571 - val_accuracy: 0.3596 - val_loss: 3.8701
# Epoch 16/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8255 - loss: 0.4404
# Epoch 16: val_accuracy did not improve from 0.64191
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 84s 181ms/step - accuracy: 0.8255 - loss: 0.4404 - val_accuracy: 0.6258 - val_loss: 1.1280
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
#
#  Generating Training Curves for Fold 4...
#  Evaluating on unseen Pure Test Set...
#
#  Generating Confusion Matrix for Fold 4...
#  Fold 4 | Acc: 64.38% | F1: 0.6349 | Precision: 0.6828 | Recall: 0.6438
#  Wiping GPU Memory clean for the next fold...
#
# ==================================================
#  STARTING FOLD 5 / 5
# ==================================================
#
#  Training Model...
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 20 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.3932 - loss: 1.2784
# Epoch 1: val_accuracy improved from -inf to 0.22129, saving model to /kaggle/working/best_customcnn_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 86s 179ms/step - accuracy: 0.3933 - loss: 1.2782 - val_accuracy: 0.2213 - val_loss: 1.7982
# Epoch 2/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.5085 - loss: 1.0646
# Epoch 2: val_accuracy improved from 0.22129 to 0.55401, saving model to /kaggle/working/best_customcnn_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.5085 - loss: 1.0645 - val_accuracy: 0.5540 - val_loss: 0.9724
# Epoch 3/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5592 - loss: 0.9615
# Epoch 3: val_accuracy improved from 0.55401 to 0.60167, saving model to /kaggle/working/best_customcnn_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.5593 - loss: 0.9615 - val_accuracy: 0.6017 - val_loss: 0.8765
# Epoch 4/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5970 - loss: 0.8767
# Epoch 4: val_accuracy improved from 0.60167 to 0.61127, saving model to /kaggle/working/best_customcnn_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.5970 - loss: 0.8767 - val_accuracy: 0.6113 - val_loss: 0.8240
# Epoch 5/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6184 - loss: 0.8242
# Epoch 5: val_accuracy did not improve from 0.61127
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.6184 - loss: 0.8242 - val_accuracy: 0.5794 - val_loss: 0.8995
# Epoch 6/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6417 - loss: 0.7874
# Epoch 6: val_accuracy did not improve from 0.61127
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.6418 - loss: 0.7873 - val_accuracy: 0.4661 - val_loss: 1.0605
# Epoch 7/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6563 - loss: 0.7490
# Epoch 7: val_accuracy improved from 0.61127 to 0.64841, saving model to /kaggle/working/best_customcnn_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 179ms/step - accuracy: 0.6563 - loss: 0.7490 - val_accuracy: 0.6484 - val_loss: 0.7938
# Epoch 8/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6737 - loss: 0.7142
# Epoch 8: val_accuracy did not improve from 0.64841
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.6737 - loss: 0.7141 - val_accuracy: 0.3129 - val_loss: 1.7857
# Epoch 9/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6860 - loss: 0.6934
# Epoch 9: val_accuracy did not improve from 0.64841
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 175ms/step - accuracy: 0.6860 - loss: 0.6933 - val_accuracy: 0.6054 - val_loss: 0.8421
# Epoch 10/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7098 - loss: 0.6536
# Epoch 10: val_accuracy did not improve from 0.64841
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 176ms/step - accuracy: 0.7098 - loss: 0.6536 - val_accuracy: 0.5150 - val_loss: 1.2777
# Epoch 11/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7316 - loss: 0.6146
# Epoch 11: val_accuracy did not improve from 0.64841
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.7316 - loss: 0.6145 - val_accuracy: 0.3327 - val_loss: 3.8451
# Epoch 12/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7511 - loss: 0.5804
# Epoch 12: val_accuracy did not improve from 0.64841
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 177ms/step - accuracy: 0.7512 - loss: 0.5804 - val_accuracy: 0.5949 - val_loss: 1.1261
# Epoch 13/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7700 - loss: 0.5456
# Epoch 13: val_accuracy improved from 0.64841 to 0.67038, saving model to /kaggle/working/best_customcnn_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.7700 - loss: 0.5455 - val_accuracy: 0.6704 - val_loss: 0.7066
# Epoch 14/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7867 - loss: 0.5198
# Epoch 14: val_accuracy improved from 0.67038 to 0.75426, saving model to /kaggle/working/best_customcnn_fold_5.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.7867 - loss: 0.5198 - val_accuracy: 0.7543 - val_loss: 0.5398
# Epoch 15/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7994 - loss: 0.4826
# Epoch 15: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 179ms/step - accuracy: 0.7994 - loss: 0.4826 - val_accuracy: 0.3188 - val_loss: 5.2090
# Epoch 16/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8085 - loss: 0.4679
# Epoch 16: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.8086 - loss: 0.4678 - val_accuracy: 0.6800 - val_loss: 1.0073
# Epoch 17/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8299 - loss: 0.4221
# Epoch 17: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.8299 - loss: 0.4221 - val_accuracy: 0.5642 - val_loss: 1.4038
# Epoch 18/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8404 - loss: 0.4061
# Epoch 18: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8404 - loss: 0.4061 - val_accuracy: 0.6512 - val_loss: 1.4213
# Epoch 19/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8525 - loss: 0.3757
# Epoch 19: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8525 - loss: 0.3757 - val_accuracy: 0.6908 - val_loss: 0.6613
# Epoch 20/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8642 - loss: 0.3469
# Epoch 20: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.8642 - loss: 0.3469 - val_accuracy: 0.2408 - val_loss: 5.2270
# Epoch 21/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8752 - loss: 0.3274
# Epoch 21: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.8752 - loss: 0.3274 - val_accuracy: 0.6320 - val_loss: 1.5401
# Epoch 22/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8786 - loss: 0.3173
# Epoch 22: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 81s 174ms/step - accuracy: 0.8786 - loss: 0.3173 - val_accuracy: 0.4825 - val_loss: 2.0227
# Epoch 23/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8910 - loss: 0.2923
# Epoch 23: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 175ms/step - accuracy: 0.8910 - loss: 0.2923 - val_accuracy: 0.6029 - val_loss: 2.0468
# Epoch 24/50
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8972 - loss: 0.2685
# Epoch 24: val_accuracy did not improve from 0.75426
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.8972 - loss: 0.2685 - val_accuracy: 0.3739 - val_loss: 3.0546
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
#
#  Generating Training Curves for Fold 5...
#  Evaluating on unseen Pure Test Set...
#
#  Generating Confusion Matrix for Fold 5...
#  Fold 5 | Acc: 75.83% | F1: 0.7431 | Precision: 0.7756 | Recall: 0.7583
#  Wiping GPU Memory clean for the next fold...
#
#  ALL 5 FOLDS COMPLETE!
#  Avg Accuracy  : 72.59% (+/- 5.27%)
#  Avg F1 Score  : 0.7137 (+/- 0.0525)
#  Avg Precision : 0.7668 (+/- 0.0558)
#  Avg Recall    : 0.7259 (+/- 0.0527)
#  Total Experiment Time: 152.85 minutes
